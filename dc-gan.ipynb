# %%
# --- Imports ---
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
from PIL import Image

# --- Hyperparameters ---
latent_dim = 128
img_size = 32
channels = 3
lr = 0.0002
b1, b2 = 0.5, 0.999
batch_size = 64
num_epochs = 200
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# --- Custom Data Loading Functions ---
def list_images(basePath, contains=None):
    # return the set of files that are valid
    return list_files(basePath, validExts=(".jpg", ".jpeg", ".png", ".bmp"), contains=contains)

def list_files(basePath, validExts=(".jpg", ".jpeg", ".png", ".bmp"), contains=None):
    # loop over the directory structure
    for (rootDir, dirNames, filenames) in os.walk(basePath):
        # loop over the filenames in the current directory
        for filename in filenames:
            # if the contains string is not none and the filename does not contain
            # the supplied string, then ignore the file
            if contains is not None and filename.find(contains) == -1:
                continue

            # determine the file extension of the current file
            ext = filename[filename.rfind("."):].lower()

            # check to see if the file is an image and should be processed
            if ext.endswith(validExts):
                # construct the path to the image and yield it
                imagePath = os.path.join(rootDir, filename).replace(" ", "\\ ")
                yield imagePath

def load_images(directory='', size=(64,64)):
    images = []
    labels = []  # Integers corresponding to the categories in alphabetical order
    label = 0
    
    imagePaths = list(list_images(directory))
    
    for path in imagePaths:
        
        if not('OSX' in path):
        
            path = path.replace('\\','/')

            image = cv2.imread(path) #Reading the image with OpenCV
            if image is not None:  # Check if image was loaded successfully
                image = cv2.resize(image, size) #Resizing the image, in case some are not of the same size
                images.append(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    
    return images

# --- Custom Dataset Class ---
class CustomImageDataset(Dataset):
    def __init__(self, directory, img_size=32, transform=None):
        self.images = load_images(directory, size=(img_size, img_size))
        self.transform = transform
        
    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, idx):
        image = self.images[idx]
        
        # Convert numpy array to PIL Image for transforms
        image = Image.fromarray(image.astype('uint8'))
        
        if self.transform:
            image = self.transform(image)
            
        return image, 0  # Return dummy label since we don't need it for GAN

# --- Generator ---
class Generator(nn.Module):
    def __init__(self, latent_dim, channels):
        super(Generator, self).__init__()
        self.model = nn.Sequential(
            nn.ConvTranspose2d(latent_dim, 512, 4, 1, 0),
            nn.BatchNorm2d(512),
            nn.ReLU(True),

            nn.ConvTranspose2d(512, 256, 4, 2, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(True),

            nn.ConvTranspose2d(256, 128, 4, 2, 1),
            nn.BatchNorm2d(128),
            nn.ReLU(True),

            nn.ConvTranspose2d(128, channels, 4, 2, 1),
            nn.Tanh()
        )

    def forward(self, z):
        return self.model(z)

# --- Discriminator ---
class Discriminator(nn.Module):
    def __init__(self, channels):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(channels, 128, 4, 2, 1),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(128, 256, 4, 2, 1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(256, 512, 4, 2, 1),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(512, 1, 4, 1, 0),
            nn.Sigmoid()
        )

    def forward(self, img):
        return self.model(img).view(-1, 1)

# --- Loss & Optimizers ---
adversarial_loss = nn.BCELoss()
generator = Generator(latent_dim, channels).to(device)
discriminator = Discriminator(channels).to(device)
optimizer_G = optim.Adam(generator.parameters(), lr=lr, betas=(b1, b2))
optimizer_D = optim.Adam(discriminator.parameters(), lr=lr, betas=(b1, b2))

# --- Dataset Loading ---
# For Kaggle, update this path based on how you added the dataset:

# Option 1: If you added the anime-faces dataset from Kaggle Datasets
# data_path = "/kaggle/input/anime-faces"

# Option 2: If the dataset has a 'data' folder inside
# data_path = "/kaggle/input/anime-faces/data"

# Option 3: If you're using the soumikrakshit/anime-faces dataset
data_path = "/kaggle/input/anime-faces/data"  # Most common for Kaggle datasets

# You can also check what's available in your input directory:
print("Available datasets in /kaggle/input/:")
for item in os.listdir("/kaggle/input/"):
    print(f"- {item}")
    # Check subdirectories
    item_path = f"/kaggle/input/{item}"
    if os.path.isdir(item_path):
        print(f"  Contents: {os.listdir(item_path)}")
print()

transform = transforms.Compose([
    transforms.Resize(img_size),
    transforms.CenterCrop(img_size),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*3, [0.5]*3)
])

# Create custom dataset and dataloader
dataset = CustomImageDataset(data_path, img_size=img_size, transform=transform)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=2)

print(f"Dataset loaded successfully! Total images: {len(dataset)}")

# --- Training Loop ---
for epoch in range(num_epochs):
    for i, (real_imgs, _) in enumerate(dataloader):
        real_imgs = real_imgs.to(device)
        real_labels = torch.ones(real_imgs.size(0), 1).to(device)
        fake_labels = torch.zeros(real_imgs.size(0), 1).to(device)

        # Train Discriminator
        optimizer_D.zero_grad()
        real_loss = adversarial_loss(discriminator(real_imgs), real_labels)

        z = torch.randn(real_imgs.size(0), latent_dim, 1, 1).to(device)
        fake_imgs = generator(z)
        fake_loss = adversarial_loss(discriminator(fake_imgs.detach()), fake_labels)
        d_loss = (real_loss + fake_loss) / 2
        d_loss.backward()
        optimizer_D.step()

        # Train Generator
        optimizer_G.zero_grad()
        g_loss = adversarial_loss(discriminator(fake_imgs), real_labels)
        g_loss.backward()
        optimizer_G.step()

        if (i + 1) % 200 == 0:
            print(f"[Epoch {epoch+1}/{num_epochs}] [Batch {i+1}/{len(dataloader)}] "
                  f"[D loss: {d_loss.item():.4f}] [G loss: {g_loss.item():.4f}]")

    # Save & Show Generated Images
    if (epoch + 1) % 10 == 0:
        generator.eval()
        with torch.no_grad():
            z = torch.randn(25, latent_dim, 1, 1).to(device)
            samples = generator(z).cpu()
            samples = 0.5 * samples + 0.5
            grid = torchvision.utils.make_grid(samples, nrow=5)
            plt.figure(figsize=(8, 8))
            plt.imshow(grid.permute(1, 2, 0))
            plt.title(f"Epoch {epoch+1}")
            plt.axis("off")
            plt.show()

            # Save output
            torchvision.utils.save_image(samples, f"epoch_{epoch+1}.png", nrow=5, normalize=True)
        generator.train()

print("Training completed!")
# Out:
# Available datasets in /kaggle/input/:
# - anime-faces
#   Contents: ['data']
#
# Dataset loaded successfully! Total images: 43102
# [Epoch 1/200] [Batch 200/674] [D loss: 0.3012] [G loss: 3.9933]
# [Epoch 1/200] [Batch 400/674] [D loss: 0.3613] [G loss: 3.7403]
# [Epoch 1/200] [Batch 600/674] [D loss: 0.1896] [G loss: 4.2861]
# [Epoch 2/200] [Batch 200/674] [D loss: 0.1129] [G loss: 3.8575]
# [Epoch 2/200] [Batch 400/674] [D loss: 0.3885] [G loss: 4.7638]
# [Epoch 2/200] [Batch 600/674] [D loss: 0.3181] [G loss: 3.4526]
# [Epoch 3/200] [Batch 200/674] [D loss: 0.6474] [G loss: 1.1493]
# [Epoch 3/200] [Batch 400/674] [D loss: 0.1776] [G loss: 3.1192]
# [Epoch 3/200] [Batch 600/674] [D loss: 0.1302] [G loss: 3.0329]
# [Epoch 4/200] [Batch 200/674] [D loss: 0.4280] [G loss: 4.6264]
# [Epoch 4/200] [Batch 400/674] [D loss: 0.1128] [G loss: 4.0240]
# [Epoch 4/200] [Batch 600/674] [D loss: 0.2670] [G loss: 4.3011]
# [Epoch 5/200] [Batch 200/674] [D loss: 1.8018] [G loss: 2.8021]
# [Epoch 5/200] [Batch 400/674] [D loss: 0.2215] [G loss: 2.1365]
# [Epoch 5/200] [Batch 600/674] [D loss: 0.2847] [G loss: 2.2430]
# [Epoch 6/200] [Batch 200/674] [D loss: 0.2055] [G loss: 4.2364]
# [Epoch 6/200] [Batch 400/674] [D loss: 0.1047] [G loss: 3.6008]
# [Epoch 6/200] [Batch 600/674] [D loss: 0.0997] [G loss: 3.6963]
# [Epoch 7/200] [Batch 200/674] [D loss: 0.0886] [G loss: 3.8345]
# [Epoch 7/200] [Batch 400/674] [D loss: 0.1015] [G loss: 3.2368]
# [Epoch 7/200] [Batch 600/674] [D loss: 0.7607] [G loss: 5.0707]
# [Epoch 8/200] [Batch 200/674] [D loss: 0.0546] [G loss: 3.8879]
# [Epoch 8/200] [Batch 400/674] [D loss: 0.1445] [G loss: 4.7024]
# [Epoch 8/200] [Batch 600/674] [D loss: 0.0418] [G loss: 4.3546]
# [Epoch 9/200] [Batch 200/674] [D loss: 0.6224] [G loss: 6.7067]
# [Epoch 9/200] [Batch 400/674] [D loss: 0.0745] [G loss: 4.0360]
# [Epoch 9/200] [Batch 600/674] [D loss: 0.1179] [G loss: 2.3777]
# [Epoch 10/200] [Batch 200/674] [D loss: 0.1510] [G loss: 5.7586]
# [Epoch 10/200] [Batch 400/674] [D loss: 0.1120] [G loss: 3.7811]
# [Epoch 10/200] [Batch 600/674] [D loss: 0.1204] [G loss: 6.0934]
# [Epoch 11/200] [Batch 200/674] [D loss: 0.1461] [G loss: 3.3985]
# [Epoch 11/200] [Batch 400/674] [D loss: 0.0445] [G loss: 3.7181]
# [Epoch 11/200] [Batch 600/674] [D loss: 0.2048] [G loss: 5.6017]
# [Epoch 12/200] [Batch 200/674] [D loss: 0.1058] [G loss: 3.3557]
# [Epoch 12/200] [Batch 400/674] [D loss: 0.1160] [G loss: 4.1690]
# [Epoch 12/200] [Batch 600/674] [D loss: 0.2906] [G loss: 3.9690]
# [Epoch 13/200] [Batch 200/674] [D loss: 0.0726] [G loss: 4.2473]
# [Epoch 13/200] [Batch 400/674] [D loss: 0.0407] [G loss: 5.1592]
# [Epoch 13/200] [Batch 600/674] [D loss: 0.0915] [G loss: 4.2175]
# [Epoch 14/200] [Batch 200/674] [D loss: 0.0927] [G loss: 6.3462]
# [Epoch 14/200] [Batch 400/674] [D loss: 0.0870] [G loss: 3.3308]
# [Epoch 14/200] [Batch 600/674] [D loss: 0.1084] [G loss: 4.2330]
# [Epoch 15/200] [Batch 200/674] [D loss: 0.0718] [G loss: 4.8255]
# [Epoch 15/200] [Batch 400/674] [D loss: 0.0398] [G loss: 5.9383]
# [Epoch 15/200] [Batch 600/674] [D loss: 0.0822] [G loss: 3.6764]
# [Epoch 16/200] [Batch 200/674] [D loss: 0.0564] [G loss: 4.4780]
# [Epoch 16/200] [Batch 400/674] [D loss: 0.1428] [G loss: 3.8642]
# [Epoch 16/200] [Batch 600/674] [D loss: 0.0545] [G loss: 4.0116]
# [Epoch 17/200] [Batch 200/674] [D loss: 0.1048] [G loss: 4.8069]
# [Epoch 17/200] [Batch 400/674] [D loss: 0.0569] [G loss: 4.5022]
# [Epoch 17/200] [Batch 600/674] [D loss: 0.1256] [G loss: 4.6177]
# [Epoch 18/200] [Batch 200/674] [D loss: 0.0437] [G loss: 4.3727]
# [Epoch 18/200] [Batch 400/674] [D loss: 0.0415] [G loss: 4.9903]
# [Epoch 18/200] [Batch 600/674] [D loss: 0.0752] [G loss: 4.0879]
# [Epoch 19/200] [Batch 200/674] [D loss: 0.0494] [G loss: 3.4616]
# [Epoch 19/200] [Batch 400/674] [D loss: 0.0454] [G loss: 4.3638]
# [Epoch 19/200] [Batch 600/674] [D loss: 0.0707] [G loss: 5.2307]
# [Epoch 20/200] [Batch 200/674] [D loss: 0.0658] [G loss: 6.4378]
# [Epoch 20/200] [Batch 400/674] [D loss: 0.0681] [G loss: 4.6756]
# [Epoch 20/200] [Batch 600/674] [D loss: 0.0694] [G loss: 4.8755]
# [Epoch 21/200] [Batch 200/674] [D loss: 0.0674] [G loss: 5.0144]
# [Epoch 21/200] [Batch 400/674] [D loss: 0.0572] [G loss: 4.9889]
# [Epoch 21/200] [Batch 600/674] [D loss: 0.0455] [G loss: 5.3703]
# [Epoch 22/200] [Batch 200/674] [D loss: 0.1305] [G loss: 4.2611]
# [Epoch 22/200] [Batch 400/674] [D loss: 0.0759] [G loss: 5.4298]
# [Epoch 22/200] [Batch 600/674] [D loss: 0.0465] [G loss: 4.6533]
# [Epoch 23/200] [Batch 200/674] [D loss: 0.0308] [G loss: 4.5348]
# [Epoch 23/200] [Batch 400/674] [D loss: 0.1561] [G loss: 4.7276]
# [Epoch 23/200] [Batch 600/674] [D loss: 0.0349] [G loss: 4.7974]
# [Epoch 24/200] [Batch 200/674] [D loss: 0.0318] [G loss: 4.6789]
# [Epoch 24/200] [Batch 400/674] [D loss: 0.0488] [G loss: 5.4141]
# [Epoch 24/200] [Batch 600/674] [D loss: 0.6432] [G loss: 1.3550]
# [Epoch 25/200] [Batch 200/674] [D loss: 0.0739] [G loss: 4.1708]
# [Epoch 25/200] [Batch 400/674] [D loss: 0.2638] [G loss: 4.9220]
# [Epoch 25/200] [Batch 600/674] [D loss: 0.0334] [G loss: 4.4179]
# [Epoch 26/200] [Batch 200/674] [D loss: 0.2251] [G loss: 3.0694]
# [Epoch 26/200] [Batch 400/674] [D loss: 0.0262] [G loss: 5.2522]
# [Epoch 26/200] [Batch 600/674] [D loss: 0.0194] [G loss: 5.2529]
# [Epoch 27/200] [Batch 200/674] [D loss: 0.0293] [G loss: 5.0047]
# [Epoch 27/200] [Batch 400/674] [D loss: 0.0518] [G loss: 5.2632]
# [Epoch 27/200] [Batch 600/674] [D loss: 0.0469] [G loss: 4.5134]
# [Epoch 28/200] [Batch 200/674] [D loss: 0.0311] [G loss: 5.7244]
# [Epoch 28/200] [Batch 400/674] [D loss: 0.0222] [G loss: 5.3241]
# [Epoch 28/200] [Batch 600/674] [D loss: 0.5852] [G loss: 5.4502]
# [Epoch 29/200] [Batch 200/674] [D loss: 0.0465] [G loss: 5.1459]
# [Epoch 29/200] [Batch 400/674] [D loss: 0.0434] [G loss: 5.4333]
# [Epoch 29/200] [Batch 600/674] [D loss: 0.2826] [G loss: 2.2402]
# [Epoch 30/200] [Batch 200/674] [D loss: 0.0196] [G loss: 5.3897]
# [Epoch 30/200] [Batch 400/674] [D loss: 0.1430] [G loss: 5.6724]
# [Epoch 30/200] [Batch 600/674] [D loss: 0.0893] [G loss: 6.6217]
# [Epoch 31/200] [Batch 200/674] [D loss: 0.0151] [G loss: 5.3956]
# [Epoch 31/200] [Batch 400/674] [D loss: 0.0220] [G loss: 5.3902]
# [Epoch 31/200] [Batch 600/674] [D loss: 0.0259] [G loss: 5.7066]
# [Epoch 32/200] [Batch 200/674] [D loss: 0.1830] [G loss: 5.0308]
# [Epoch 32/200] [Batch 400/674] [D loss: 0.0572] [G loss: 4.9861]
# [Epoch 32/200] [Batch 600/674] [D loss: 0.0680] [G loss: 4.6802]
# [Epoch 33/200] [Batch 200/674] [D loss: 0.0251] [G loss: 4.6196]
# [Epoch 33/200] [Batch 400/674] [D loss: 0.0240] [G loss: 5.2014]
# [Epoch 33/200] [Batch 600/674] [D loss: 0.1961] [G loss: 5.7795]
# [Epoch 34/200] [Batch 200/674] [D loss: 0.0505] [G loss: 4.8512]
# [Epoch 34/200] [Batch 400/674] [D loss: 0.0297] [G loss: 4.4676]
# [Epoch 34/200] [Batch 600/674] [D loss: 0.6834] [G loss: 1.2607]
# [Epoch 35/200] [Batch 200/674] [D loss: 0.0328] [G loss: 4.7147]
# [Epoch 35/200] [Batch 400/674] [D loss: 0.0339] [G loss: 4.1607]
# [Epoch 35/200] [Batch 600/674] [D loss: 0.0474] [G loss: 5.2008]
# [Epoch 36/200] [Batch 200/674] [D loss: 0.0221] [G loss: 5.7352]
# [Epoch 36/200] [Batch 400/674] [D loss: 0.0205] [G loss: 5.1473]
# [Epoch 36/200] [Batch 600/674] [D loss: 1.3625] [G loss: 5.7060]
# [Epoch 37/200] [Batch 200/674] [D loss: 0.0333] [G loss: 5.1202]
# [Epoch 37/200] [Batch 400/674] [D loss: 0.0433] [G loss: 5.8210]
# [Epoch 37/200] [Batch 600/674] [D loss: 0.0555] [G loss: 5.5851]
# [Epoch 38/200] [Batch 200/674] [D loss: 0.0072] [G loss: 6.1187]
# [Epoch 38/200] [Batch 400/674] [D loss: 0.0752] [G loss: 4.5021]
# [Epoch 38/200] [Batch 600/674] [D loss: 0.0271] [G loss: 5.5467]
# [Epoch 39/200] [Batch 200/674] [D loss: 0.0232] [G loss: 5.5287]
# [Epoch 39/200] [Batch 400/674] [D loss: 0.0142] [G loss: 5.5353]
# [Epoch 39/200] [Batch 600/674] [D loss: 0.0595] [G loss: 4.5544]
# [Epoch 40/200] [Batch 200/674] [D loss: 0.0368] [G loss: 5.9758]
# [Epoch 40/200] [Batch 400/674] [D loss: 0.0285] [G loss: 5.1068]
# [Epoch 40/200] [Batch 600/674] [D loss: 0.0505] [G loss: 5.2377]
# [Epoch 41/200] [Batch 200/674] [D loss: 0.0259] [G loss: 5.9556]
# [Epoch 41/200] [Batch 400/674] [D loss: 0.0164] [G loss: 5.1470]
# [Epoch 41/200] [Batch 600/674] [D loss: 0.0090] [G loss: 5.1645]
# [Epoch 42/200] [Batch 200/674] [D loss: 0.0299] [G loss: 5.3844]
# [Epoch 42/200] [Batch 400/674] [D loss: 0.0375] [G loss: 5.1424]
# [Epoch 42/200] [Batch 600/674] [D loss: 0.0243] [G loss: 5.1570]
# [Epoch 43/200] [Batch 200/674] [D loss: 0.0259] [G loss: 5.6493]
# [Epoch 43/200] [Batch 400/674] [D loss: 0.1833] [G loss: 8.0299]
# [Epoch 43/200] [Batch 600/674] [D loss: 0.0450] [G loss: 4.1064]
# [Epoch 44/200] [Batch 200/674] [D loss: 0.0137] [G loss: 6.4384]
# [Epoch 44/200] [Batch 400/674] [D loss: 0.0212] [G loss: 5.6094]
# [Epoch 44/200] [Batch 600/674] [D loss: 0.0304] [G loss: 5.6124]
# [Epoch 45/200] [Batch 200/674] [D loss: 0.0094] [G loss: 5.8740]
# [Epoch 45/200] [Batch 400/674] [D loss: 0.3432] [G loss: 8.8160]
# [Epoch 45/200] [Batch 600/674] [D loss: 0.0494] [G loss: 4.6197]
# [Epoch 46/200] [Batch 200/674] [D loss: 0.0326] [G loss: 4.8645]
# [Epoch 46/200] [Batch 400/674] [D loss: 0.0187] [G loss: 5.6491]
# [Epoch 46/200] [Batch 600/674] [D loss: 0.0171] [G loss: 6.1255]
# [Epoch 47/200] [Batch 200/674] [D loss: 0.1026] [G loss: 4.8017]
# [Epoch 47/200] [Batch 400/674] [D loss: 0.0454] [G loss: 4.9303]
# [Epoch 47/200] [Batch 600/674] [D loss: 0.0446] [G loss: 4.2608]
# [Epoch 48/200] [Batch 200/674] [D loss: 0.0670] [G loss: 5.0531]
# [Epoch 48/200] [Batch 400/674] [D loss: 0.0320] [G loss: 5.9323]
# [Epoch 48/200] [Batch 600/674] [D loss: 0.0196] [G loss: 5.5530]
# [Epoch 49/200] [Batch 200/674] [D loss: 0.0129] [G loss: 5.5970]
# [Epoch 49/200] [Batch 400/674] [D loss: 0.0157] [G loss: 5.3449]
# [Epoch 49/200] [Batch 600/674] [D loss: 0.0249] [G loss: 5.4600]
# [Epoch 50/200] [Batch 200/674] [D loss: 0.0421] [G loss: 4.7728]
# [Epoch 50/200] [Batch 400/674] [D loss: 0.0238] [G loss: 5.4441]
# [Epoch 50/200] [Batch 600/674] [D loss: 0.0084] [G loss: 5.8625]
# [Epoch 51/200] [Batch 200/674] [D loss: 0.0159] [G loss: 5.9644]
# [Epoch 51/200] [Batch 400/674] [D loss: 0.0095] [G loss: 6.2135]
# [Epoch 51/200] [Batch 600/674] [D loss: 0.0182] [G loss: 5.7764]
# [Epoch 52/200] [Batch 200/674] [D loss: 0.0069] [G loss: 6.3739]
# [Epoch 52/200] [Batch 400/674] [D loss: 0.3028] [G loss: 3.7994]
# [Epoch 52/200] [Batch 600/674] [D loss: 0.0528] [G loss: 4.7723]
# [Epoch 53/200] [Batch 200/674] [D loss: 0.0289] [G loss: 6.7993]
# [Epoch 53/200] [Batch 400/674] [D loss: 0.0223] [G loss: 5.5983]
# [Epoch 53/200] [Batch 600/674] [D loss: 0.0128] [G loss: 6.0587]
# [Epoch 54/200] [Batch 200/674] [D loss: 0.0167] [G loss: 5.8188]
# [Epoch 54/200] [Batch 400/674] [D loss: 0.0286] [G loss: 5.2674]
# [Epoch 54/200] [Batch 600/674] [D loss: 0.1582] [G loss: 3.6934]
# [Epoch 55/200] [Batch 200/674] [D loss: 0.0250] [G loss: 4.5111]
# [Epoch 55/200] [Batch 400/674] [D loss: 0.0142] [G loss: 5.5211]
# [Epoch 55/200] [Batch 600/674] [D loss: 0.0277] [G loss: 5.2677]
# [Epoch 56/200] [Batch 200/674] [D loss: 0.0107] [G loss: 6.0362]
# [Epoch 56/200] [Batch 400/674] [D loss: 0.0242] [G loss: 6.2821]
# [Epoch 56/200] [Batch 600/674] [D loss: 0.0041] [G loss: 6.2802]
# [Epoch 57/200] [Batch 200/674] [D loss: 0.0034] [G loss: 7.0016]
# [Epoch 57/200] [Batch 400/674] [D loss: 0.6519] [G loss: 8.5607]
# [Epoch 57/200] [Batch 600/674] [D loss: 0.0274] [G loss: 5.2902]
# [Epoch 58/200] [Batch 200/674] [D loss: 0.0229] [G loss: 5.2896]
# [Epoch 58/200] [Batch 400/674] [D loss: 0.0256] [G loss: 5.3124]
# [Epoch 58/200] [Batch 600/674] [D loss: 0.0125] [G loss: 5.9034]
# [Epoch 59/200] [Batch 200/674] [D loss: 0.0098] [G loss: 5.8860]
# [Epoch 59/200] [Batch 400/674] [D loss: 0.0118] [G loss: 6.4886]
# [Epoch 59/200] [Batch 600/674] [D loss: 0.0423] [G loss: 4.1493]
# [Epoch 60/200] [Batch 200/674] [D loss: 0.0101] [G loss: 5.8940]
# [Epoch 60/200] [Batch 400/674] [D loss: 0.1838] [G loss: 6.2456]
# [Epoch 60/200] [Batch 600/674] [D loss: 0.0404] [G loss: 6.4207]
# [Epoch 61/200] [Batch 200/674] [D loss: 0.0222] [G loss: 6.0410]
# [Epoch 61/200] [Batch 400/674] [D loss: 0.0172] [G loss: 5.8070]
# [Epoch 61/200] [Batch 600/674] [D loss: 0.0171] [G loss: 5.8825]
# [Epoch 62/200] [Batch 200/674] [D loss: 0.0199] [G loss: 5.6415]
# [Epoch 62/200] [Batch 400/674] [D loss: 0.0731] [G loss: 5.5628]
# [Epoch 62/200] [Batch 600/674] [D loss: 0.0242] [G loss: 5.6285]
# [Epoch 63/200] [Batch 200/674] [D loss: 0.0096] [G loss: 6.2974]
# [Epoch 63/200] [Batch 400/674] [D loss: 0.0142] [G loss: 5.8707]
# [Epoch 63/200] [Batch 600/674] [D loss: 0.0263] [G loss: 6.4572]
# [Epoch 64/200] [Batch 200/674] [D loss: 0.0269] [G loss: 8.2790]
# [Epoch 64/200] [Batch 400/674] [D loss: 0.0166] [G loss: 4.8289]
# [Epoch 64/200] [Batch 600/674] [D loss: 0.0047] [G loss: 6.6394]
# [Epoch 65/200] [Batch 200/674] [D loss: 0.4103] [G loss: 8.7085]
# [Epoch 65/200] [Batch 400/674] [D loss: 0.0518] [G loss: 4.8415]
# [Epoch 65/200] [Batch 600/674] [D loss: 0.0148] [G loss: 5.4703]
# [Epoch 66/200] [Batch 200/674] [D loss: 0.0103] [G loss: 5.7735]
# [Epoch 66/200] [Batch 400/674] [D loss: 0.0111] [G loss: 7.0058]
# [Epoch 66/200] [Batch 600/674] [D loss: 0.0248] [G loss: 5.9890]
# [Epoch 67/200] [Batch 200/674] [D loss: 0.0077] [G loss: 6.8411]
# [Epoch 67/200] [Batch 400/674] [D loss: 0.0116] [G loss: 6.2485]
# [Epoch 67/200] [Batch 600/674] [D loss: 0.0764] [G loss: 6.0705]
# [Epoch 68/200] [Batch 200/674] [D loss: 0.0237] [G loss: 5.7633]
# [Epoch 68/200] [Batch 400/674] [D loss: 0.0254] [G loss: 5.6015]
# [Epoch 68/200] [Batch 600/674] [D loss: 0.0120] [G loss: 6.2758]
# [Epoch 69/200] [Batch 200/674] [D loss: 0.0097] [G loss: 6.2113]
# [Epoch 69/200] [Batch 400/674] [D loss: 0.0087] [G loss: 6.3791]
# [Epoch 69/200] [Batch 600/674] [D loss: 0.0164] [G loss: 5.8123]
# [Epoch 70/200] [Batch 200/674] [D loss: 0.0412] [G loss: 5.6348]
# [Epoch 70/200] [Batch 400/674] [D loss: 0.0333] [G loss: 5.9189]
# [Epoch 70/200] [Batch 600/674] [D loss: 0.0062] [G loss: 6.7458]
# [Epoch 71/200] [Batch 200/674] [D loss: 0.0085] [G loss: 6.1276]
# [Epoch 71/200] [Batch 400/674] [D loss: 0.0107] [G loss: 6.4392]
# [Epoch 71/200] [Batch 600/674] [D loss: 0.0096] [G loss: 6.8662]
# [Epoch 72/200] [Batch 200/674] [D loss: 0.0081] [G loss: 6.4980]
# [Epoch 72/200] [Batch 400/674] [D loss: 0.0090] [G loss: 6.6469]
# [Epoch 72/200] [Batch 600/674] [D loss: 0.0069] [G loss: 7.4514]
# [Epoch 73/200] [Batch 200/674] [D loss: 0.0063] [G loss: 6.9772]
# [Epoch 73/200] [Batch 400/674] [D loss: 0.4893] [G loss: 2.6392]
# [Epoch 73/200] [Batch 600/674] [D loss: 0.0410] [G loss: 5.9816]
# [Epoch 74/200] [Batch 200/674] [D loss: 0.0306] [G loss: 4.8847]
# [Epoch 74/200] [Batch 400/674] [D loss: 0.0157] [G loss: 6.2536]
# [Epoch 74/200] [Batch 600/674] [D loss: 0.0148] [G loss: 6.1963]
# [Epoch 75/200] [Batch 200/674] [D loss: 0.0073] [G loss: 6.6618]
# [Epoch 75/200] [Batch 400/674] [D loss: 0.0046] [G loss: 7.7690]
# [Epoch 75/200] [Batch 600/674] [D loss: 0.0102] [G loss: 6.3796]
# [Epoch 76/200] [Batch 200/674] [D loss: 0.0239] [G loss: 6.2776]
# [Epoch 76/200] [Batch 400/674] [D loss: 0.0049] [G loss: 6.9446]
# [Epoch 76/200] [Batch 600/674] [D loss: 0.1083] [G loss: 5.2980]
# [Epoch 77/200] [Batch 200/674] [D loss: 0.0214] [G loss: 6.5539]
# [Epoch 77/200] [Batch 400/674] [D loss: 0.0275] [G loss: 4.7248]
# [Epoch 77/200] [Batch 600/674] [D loss: 0.0108] [G loss: 6.8107]
# [Epoch 78/200] [Batch 200/674] [D loss: 0.0064] [G loss: 6.6226]
# [Epoch 78/200] [Batch 400/674] [D loss: 0.0086] [G loss: 6.1262]
# [Epoch 78/200] [Batch 600/674] [D loss: 0.4374] [G loss: 7.4691]
# [Epoch 79/200] [Batch 200/674] [D loss: 0.0232] [G loss: 6.1081]
# [Epoch 79/200] [Batch 400/674] [D loss: 0.0165] [G loss: 5.4132]
# [Epoch 79/200] [Batch 600/674] [D loss: 0.0148] [G loss: 5.9568]
# [Epoch 80/200] [Batch 200/674] [D loss: 0.0087] [G loss: 6.1768]
# [Epoch 80/200] [Batch 400/674] [D loss: 0.0278] [G loss: 5.0135]
# [Epoch 80/200] [Batch 600/674] [D loss: 0.0054] [G loss: 6.7932]
# [Epoch 81/200] [Batch 200/674] [D loss: 0.0210] [G loss: 6.9206]
# [Epoch 81/200] [Batch 400/674] [D loss: 0.0619] [G loss: 5.6727]
# [Epoch 81/200] [Batch 600/674] [D loss: 0.0197] [G loss: 5.4275]
# [Epoch 82/200] [Batch 200/674] [D loss: 0.0098] [G loss: 6.1276]
# [Epoch 82/200] [Batch 400/674] [D loss: 0.0050] [G loss: 6.5068]
# [Epoch 82/200] [Batch 600/674] [D loss: 0.0089] [G loss: 6.4634]
# [Epoch 83/200] [Batch 200/674] [D loss: 0.0122] [G loss: 6.0544]
# [Epoch 83/200] [Batch 400/674] [D loss: 0.0156] [G loss: 5.5137]
# [Epoch 83/200] [Batch 600/674] [D loss: 0.0070] [G loss: 7.1359]
# [Epoch 84/200] [Batch 200/674] [D loss: 0.9187] [G loss: 5.2151]
# [Epoch 84/200] [Batch 400/674] [D loss: 0.0282] [G loss: 7.0655]
# [Epoch 84/200] [Batch 600/674] [D loss: 0.0177] [G loss: 5.4141]
# [Epoch 85/200] [Batch 200/674] [D loss: 0.0079] [G loss: 6.6726]
# [Epoch 85/200] [Batch 400/674] [D loss: 0.0119] [G loss: 6.6764]
# [Epoch 85/200] [Batch 600/674] [D loss: 0.0053] [G loss: 6.2269]
# [Epoch 86/200] [Batch 200/674] [D loss: 0.0171] [G loss: 5.7740]
# [Epoch 86/200] [Batch 400/674] [D loss: 0.0098] [G loss: 6.7181]
# [Epoch 86/200] [Batch 600/674] [D loss: 0.0082] [G loss: 6.3943]
# [Epoch 87/200] [Batch 200/674] [D loss: 0.0034] [G loss: 7.3484]
# [Epoch 87/200] [Batch 400/674] [D loss: 0.0066] [G loss: 6.4185]
# [Epoch 87/200] [Batch 600/674] [D loss: 0.1696] [G loss: 6.1701]
# [Epoch 88/200] [Batch 200/674] [D loss: 0.0238] [G loss: 5.6034]
# [Epoch 88/200] [Batch 400/674] [D loss: 0.0185] [G loss: 6.4818]
# [Epoch 88/200] [Batch 600/674] [D loss: 0.0300] [G loss: 6.1569]
# [Epoch 89/200] [Batch 200/674] [D loss: 0.0048] [G loss: 7.1344]
# [Epoch 89/200] [Batch 400/674] [D loss: 0.0048] [G loss: 6.7697]
# [Epoch 89/200] [Batch 600/674] [D loss: 0.0180] [G loss: 6.3663]
# [Epoch 90/200] [Batch 200/674] [D loss: 0.0103] [G loss: 7.5287]
# [Epoch 90/200] [Batch 400/674] [D loss: 0.0085] [G loss: 6.6309]
# [Epoch 90/200] [Batch 600/674] [D loss: 0.0027] [G loss: 7.4676]
# [Epoch 91/200] [Batch 200/674] [D loss: 0.1703] [G loss: 6.4740]
# [Epoch 91/200] [Batch 400/674] [D loss: 0.0508] [G loss: 6.4815]
# [Epoch 91/200] [Batch 600/674] [D loss: 0.0383] [G loss: 6.7885]
# [Epoch 92/200] [Batch 200/674] [D loss: 0.0089] [G loss: 6.5519]
# [Epoch 92/200] [Batch 400/674] [D loss: 0.0163] [G loss: 6.0190]
# [Epoch 92/200] [Batch 600/674] [D loss: 0.0077] [G loss: 6.4761]
# [Epoch 93/200] [Batch 200/674] [D loss: 0.0082] [G loss: 7.1165]
# [Epoch 93/200] [Batch 400/674] [D loss: 0.0033] [G loss: 8.0968]
# [Epoch 93/200] [Batch 600/674] [D loss: 0.0054] [G loss: 6.6759]
# [Epoch 94/200] [Batch 200/674] [D loss: 0.0048] [G loss: 7.3935]
# [Epoch 94/200] [Batch 400/674] [D loss: 0.0034] [G loss: 7.7067]
# [Epoch 94/200] [Batch 600/674] [D loss: 0.0735] [G loss: 5.5395]
# [Epoch 95/200] [Batch 200/674] [D loss: 0.0248] [G loss: 6.0663]
# [Epoch 95/200] [Batch 400/674] [D loss: 0.0145] [G loss: 6.9404]
# [Epoch 95/200] [Batch 600/674] [D loss: 0.0120] [G loss: 7.4013]
# [Epoch 96/200] [Batch 200/674] [D loss: 0.0102] [G loss: 7.1749]
# [Epoch 96/200] [Batch 400/674] [D loss: 0.0143] [G loss: 6.2514]
# [Epoch 96/200] [Batch 600/674] [D loss: 0.5231] [G loss: 3.4382]
# [Epoch 97/200] [Batch 200/674] [D loss: 0.0731] [G loss: 4.1009]
# [Epoch 97/200] [Batch 400/674] [D loss: 0.0138] [G loss: 6.0397]
# [Epoch 97/200] [Batch 600/674] [D loss: 0.0174] [G loss: 6.6530]
# [Epoch 98/200] [Batch 200/674] [D loss: 0.0050] [G loss: 6.8846]
# [Epoch 98/200] [Batch 400/674] [D loss: 0.0098] [G loss: 6.5830]
# [Epoch 98/200] [Batch 600/674] [D loss: 0.0041] [G loss: 7.1847]
# [Epoch 99/200] [Batch 200/674] [D loss: 0.0080] [G loss: 7.2095]
# [Epoch 99/200] [Batch 400/674] [D loss: 0.0059] [G loss: 7.9249]
# [Epoch 99/200] [Batch 600/674] [D loss: 0.0036] [G loss: 7.4594]
# [Epoch 100/200] [Batch 200/674] [D loss: 0.0070] [G loss: 7.3719]
# [Epoch 100/200] [Batch 400/674] [D loss: 1.1364] [G loss: 5.4601]
# [Epoch 100/200] [Batch 600/674] [D loss: 0.0773] [G loss: 5.5434]
# [Epoch 101/200] [Batch 200/674] [D loss: 0.0135] [G loss: 6.0529]
# [Epoch 101/200] [Batch 400/674] [D loss: 0.0134] [G loss: 6.0281]
# [Epoch 101/200] [Batch 600/674] [D loss: 0.0174] [G loss: 5.9301]
# [Epoch 102/200] [Batch 200/674] [D loss: 0.0039] [G loss: 7.0167]
# [Epoch 102/200] [Batch 400/674] [D loss: 0.0075] [G loss: 6.4381]
# [Epoch 102/200] [Batch 600/674] [D loss: 0.0061] [G loss: 6.9179]
# [Epoch 103/200] [Batch 200/674] [D loss: 0.0092] [G loss: 6.8022]
# [Epoch 103/200] [Batch 400/674] [D loss: 0.2571] [G loss: 8.0197]
# [Epoch 103/200] [Batch 600/674] [D loss: 0.0347] [G loss: 6.5519]
# [Epoch 104/200] [Batch 200/674] [D loss: 0.0126] [G loss: 6.1121]
# [Epoch 104/200] [Batch 400/674] [D loss: 0.0181] [G loss: 5.8487]
# [Epoch 104/200] [Batch 600/674] [D loss: 0.0176] [G loss: 5.5448]
# [Epoch 105/200] [Batch 200/674] [D loss: 0.0096] [G loss: 6.2654]
# [Epoch 105/200] [Batch 400/674] [D loss: 0.0076] [G loss: 7.2459]
# [Epoch 105/200] [Batch 600/674] [D loss: 0.0138] [G loss: 8.0904]
# [Epoch 106/200] [Batch 200/674] [D loss: 0.0659] [G loss: 7.7391]
# [Epoch 106/200] [Batch 400/674] [D loss: 0.0193] [G loss: 6.6285]
# [Epoch 106/200] [Batch 600/674] [D loss: 0.0120] [G loss: 6.7873]
# [Epoch 107/200] [Batch 200/674] [D loss: 0.0068] [G loss: 7.0335]
# [Epoch 107/200] [Batch 400/674] [D loss: 0.0107] [G loss: 7.2822]
# [Epoch 107/200] [Batch 600/674] [D loss: 0.0117] [G loss: 5.9743]
# [Epoch 108/200] [Batch 200/674] [D loss: 0.0060] [G loss: 7.6516]
# [Epoch 108/200] [Batch 400/674] [D loss: 0.0068] [G loss: 7.3673]
# [Epoch 108/200] [Batch 600/674] [D loss: 0.0053] [G loss: 7.5348]
# [Epoch 109/200] [Batch 200/674] [D loss: 0.0082] [G loss: 8.0340]
# [Epoch 109/200] [Batch 400/674] [D loss: 0.0028] [G loss: 8.2073]
# [Epoch 109/200] [Batch 600/674] [D loss: 0.1491] [G loss: 4.3595]
# [Epoch 110/200] [Batch 200/674] [D loss: 0.0232] [G loss: 6.7509]
# [Epoch 110/200] [Batch 400/674] [D loss: 0.0350] [G loss: 5.2636]
# [Epoch 110/200] [Batch 600/674] [D loss: 0.0248] [G loss: 6.3531]
# [Epoch 111/200] [Batch 200/674] [D loss: 0.0109] [G loss: 6.3380]
# [Epoch 111/200] [Batch 400/674] [D loss: 0.0056] [G loss: 8.0938]
# [Epoch 111/200] [Batch 600/674] [D loss: 0.0040] [G loss: 7.7917]
# [Epoch 112/200] [Batch 200/674] [D loss: 0.0061] [G loss: 6.4117]
# [Epoch 112/200] [Batch 400/674] [D loss: 0.0100] [G loss: 8.0159]
# [Epoch 112/200] [Batch 600/674] [D loss: 0.1253] [G loss: 7.2742]
# [Epoch 113/200] [Batch 200/674] [D loss: 0.0083] [G loss: 6.8249]
# [Epoch 113/200] [Batch 400/674] [D loss: 0.0245] [G loss: 6.0060]
# [Epoch 113/200] [Batch 600/674] [D loss: 0.0101] [G loss: 6.9509]
# [Epoch 114/200] [Batch 200/674] [D loss: 0.0093] [G loss: 6.7700]
# [Epoch 114/200] [Batch 400/674] [D loss: 0.0151] [G loss: 6.3768]
# [Epoch 114/200] [Batch 600/674] [D loss: 0.0093] [G loss: 7.2697]
# [Epoch 115/200] [Batch 200/674] [D loss: 0.0161] [G loss: 8.0793]
# [Epoch 115/200] [Batch 400/674] [D loss: 0.0028] [G loss: 7.9264]
# [Epoch 115/200] [Batch 600/674] [D loss: 0.0024] [G loss: 7.3611]
# [Epoch 116/200] [Batch 200/674] [D loss: 0.1390] [G loss: 4.4855]
# [Epoch 116/200] [Batch 400/674] [D loss: 0.0187] [G loss: 6.3116]
# [Epoch 116/200] [Batch 600/674] [D loss: 0.0162] [G loss: 5.9934]
# [Epoch 117/200] [Batch 200/674] [D loss: 0.0156] [G loss: 6.7337]
# [Epoch 117/200] [Batch 400/674] [D loss: 0.0160] [G loss: 6.1629]
# [Epoch 117/200] [Batch 600/674] [D loss: 0.0053] [G loss: 8.0210]
# [Epoch 118/200] [Batch 200/674] [D loss: 0.0034] [G loss: 7.9967]
# [Epoch 118/200] [Batch 400/674] [D loss: 0.0070] [G loss: 7.3800]
# [Epoch 118/200] [Batch 600/674] [D loss: 0.6296] [G loss: 2.4946]
# [Epoch 119/200] [Batch 200/674] [D loss: 0.0346] [G loss: 6.1533]
# [Epoch 119/200] [Batch 400/674] [D loss: 0.0136] [G loss: 6.5066]
# [Epoch 119/200] [Batch 600/674] [D loss: 0.0100] [G loss: 7.3354]
# [Epoch 120/200] [Batch 200/674] [D loss: 0.0090] [G loss: 6.9833]
# [Epoch 120/200] [Batch 400/674] [D loss: 0.0047] [G loss: 7.1344]
# [Epoch 120/200] [Batch 600/674] [D loss: 0.0041] [G loss: 8.2947]
# [Epoch 121/200] [Batch 200/674] [D loss: 0.0029] [G loss: 8.0004]
# [Epoch 121/200] [Batch 400/674] [D loss: 0.0020] [G loss: 8.0659]
# [Epoch 121/200] [Batch 600/674] [D loss: 0.6942] [G loss: 10.9149]
# [Epoch 122/200] [Batch 200/674] [D loss: 0.0324] [G loss: 6.8541]
# [Epoch 122/200] [Batch 400/674] [D loss: 0.0155] [G loss: 7.4256]
# [Epoch 122/200] [Batch 600/674] [D loss: 0.0121] [G loss: 6.9300]
# [Epoch 123/200] [Batch 200/674] [D loss: 0.0043] [G loss: 6.2751]
# [Epoch 123/200] [Batch 400/674] [D loss: 0.0073] [G loss: 7.2863]
# [Epoch 123/200] [Batch 600/674] [D loss: 0.0088] [G loss: 7.5064]
# [Epoch 124/200] [Batch 200/674] [D loss: 0.0060] [G loss: 7.3295]
# [Epoch 124/200] [Batch 400/674] [D loss: 0.1047] [G loss: 6.9168]
# [Epoch 124/200] [Batch 600/674] [D loss: 0.0125] [G loss: 7.6679]
# [Epoch 125/200] [Batch 200/674] [D loss: 0.0064] [G loss: 6.5021]
# [Epoch 125/200] [Batch 400/674] [D loss: 0.0084] [G loss: 7.0760]
# [Epoch 125/200] [Batch 600/674] [D loss: 0.0078] [G loss: 6.9408]
# [Epoch 126/200] [Batch 200/674] [D loss: 0.0047] [G loss: 7.2523]
# [Epoch 126/200] [Batch 400/674] [D loss: 0.0061] [G loss: 7.7437]
# [Epoch 126/200] [Batch 600/674] [D loss: 0.0054] [G loss: 7.4575]
# [Epoch 127/200] [Batch 200/674] [D loss: 0.2969] [G loss: 8.1433]
# [Epoch 127/200] [Batch 400/674] [D loss: 0.0229] [G loss: 6.7246]
# [Epoch 127/200] [Batch 600/674] [D loss: 0.0164] [G loss: 6.5838]
# [Epoch 128/200] [Batch 200/674] [D loss: 0.0191] [G loss: 7.7203]
# [Epoch 128/200] [Batch 400/674] [D loss: 0.0146] [G loss: 6.7945]
# [Epoch 128/200] [Batch 600/674] [D loss: 0.0031] [G loss: 8.2142]
# [Epoch 129/200] [Batch 200/674] [D loss: 0.0109] [G loss: 7.3001]
# [Epoch 129/200] [Batch 400/674] [D loss: 0.0034] [G loss: 7.5950]
# [Epoch 129/200] [Batch 600/674] [D loss: 0.0027] [G loss: 7.4231]
# [Epoch 130/200] [Batch 200/674] [D loss: 0.0022] [G loss: 8.6414]
# [Epoch 130/200] [Batch 400/674] [D loss: 0.0047] [G loss: 7.9291]
# [Epoch 130/200] [Batch 600/674] [D loss: 0.5499] [G loss: 1.1676]
# [Epoch 131/200] [Batch 200/674] [D loss: 0.0096] [G loss: 6.4479]
# [Epoch 131/200] [Batch 400/674] [D loss: 0.0096] [G loss: 6.2382]
# [Epoch 131/200] [Batch 600/674] [D loss: 0.0185] [G loss: 6.7484]
# [Epoch 132/200] [Batch 200/674] [D loss: 0.0107] [G loss: 7.5537]
# [Epoch 132/200] [Batch 400/674] [D loss: 0.0066] [G loss: 7.6669]
# [Epoch 132/200] [Batch 600/674] [D loss: 0.0043] [G loss: 7.1432]
# [Epoch 133/200] [Batch 200/674] [D loss: 0.0023] [G loss: 7.7706]
# [Epoch 133/200] [Batch 400/674] [D loss: 0.0035] [G loss: 7.2399]
# [Epoch 133/200] [Batch 600/674] [D loss: 0.0087] [G loss: 7.3568]
# [Epoch 134/200] [Batch 200/674] [D loss: 0.3351] [G loss: 2.5596]
# [Epoch 134/200] [Batch 400/674] [D loss: 0.0273] [G loss: 6.0002]
# [Epoch 134/200] [Batch 600/674] [D loss: 0.0156] [G loss: 6.4306]
# [Epoch 135/200] [Batch 200/674] [D loss: 0.0051] [G loss: 7.3955]
# [Epoch 135/200] [Batch 400/674] [D loss: 0.0095] [G loss: 6.9561]
# [Epoch 135/200] [Batch 600/674] [D loss: 0.0050] [G loss: 7.7169]
# [Epoch 136/200] [Batch 200/674] [D loss: 0.0071] [G loss: 8.0511]
# [Epoch 136/200] [Batch 400/674] [D loss: 0.0073] [G loss: 7.5977]
# [Epoch 136/200] [Batch 600/674] [D loss: 0.0033] [G loss: 7.7511]
# [Epoch 137/200] [Batch 200/674] [D loss: 0.0038] [G loss: 7.6637]
# [Epoch 137/200] [Batch 400/674] [D loss: 0.0025] [G loss: 8.4056]
# [Epoch 137/200] [Batch 600/674] [D loss: 0.0107] [G loss: 8.7779]
# [Epoch 138/200] [Batch 200/674] [D loss: 0.0141] [G loss: 7.1757]
# [Epoch 138/200] [Batch 400/674] [D loss: 0.0050] [G loss: 7.4796]
# [Epoch 138/200] [Batch 600/674] [D loss: 0.0109] [G loss: 7.5512]
# [Epoch 139/200] [Batch 200/674] [D loss: 0.0107] [G loss: 6.7810]
# [Epoch 139/200] [Batch 400/674] [D loss: 0.0068] [G loss: 7.2379]
# [Epoch 139/200] [Batch 600/674] [D loss: 0.0039] [G loss: 7.4970]
# [Epoch 140/200] [Batch 200/674] [D loss: 0.0045] [G loss: 7.4329]
# [Epoch 140/200] [Batch 400/674] [D loss: 0.0023] [G loss: 7.6751]
# [Epoch 140/200] [Batch 600/674] [D loss: 0.0048] [G loss: 7.7160]
# [Epoch 141/200] [Batch 200/674] [D loss: 0.0408] [G loss: 6.2997]
# [Epoch 141/200] [Batch 400/674] [D loss: 0.0213] [G loss: 6.8389]
# [Epoch 141/200] [Batch 600/674] [D loss: 0.0152] [G loss: 7.0599]
# [Epoch 142/200] [Batch 200/674] [D loss: 0.0060] [G loss: 6.7501]
# [Epoch 142/200] [Batch 400/674] [D loss: 0.0119] [G loss: 8.4229]
# [Epoch 142/200] [Batch 600/674] [D loss: 0.0046] [G loss: 7.0159]
# [Epoch 143/200] [Batch 200/674] [D loss: 0.0032] [G loss: 7.8499]
# [Epoch 143/200] [Batch 400/674] [D loss: 0.0038] [G loss: 7.9979]
# [Epoch 143/200] [Batch 600/674] [D loss: 0.0076] [G loss: 7.6333]
# [Epoch 144/200] [Batch 200/674] [D loss: 0.5552] [G loss: 7.2906]
# [Epoch 144/200] [Batch 400/674] [D loss: 0.0307] [G loss: 7.3125]
# [Epoch 144/200] [Batch 600/674] [D loss: 0.0172] [G loss: 6.8247]
# [Epoch 145/200] [Batch 200/674] [D loss: 0.0100] [G loss: 7.8043]
# [Epoch 145/200] [Batch 400/674] [D loss: 0.0115] [G loss: 8.6089]
# [Epoch 145/200] [Batch 600/674] [D loss: 0.0141] [G loss: 6.8753]
# [Epoch 146/200] [Batch 200/674] [D loss: 0.0051] [G loss: 7.4776]
# [Epoch 146/200] [Batch 400/674] [D loss: 0.0047] [G loss: 7.9732]
# [Epoch 146/200] [Batch 600/674] [D loss: 0.0035] [G loss: 8.1635]
# [Epoch 147/200] [Batch 200/674] [D loss: 0.0219] [G loss: 7.6466]
# [Epoch 147/200] [Batch 400/674] [D loss: 0.1362] [G loss: 8.1474]
# [Epoch 147/200] [Batch 600/674] [D loss: 0.0219] [G loss: 6.2302]
# [Epoch 148/200] [Batch 200/674] [D loss: 0.0049] [G loss: 7.1240]
# [Epoch 148/200] [Batch 400/674] [D loss: 0.0164] [G loss: 6.9005]
# [Epoch 148/200] [Batch 600/674] [D loss: 0.0115] [G loss: 7.3245]
# [Epoch 149/200] [Batch 200/674] [D loss: 0.0073] [G loss: 8.0500]
# [Epoch 149/200] [Batch 400/674] [D loss: 0.0026] [G loss: 7.7497]
# [Epoch 149/200] [Batch 600/674] [D loss: 0.0049] [G loss: 8.3904]
# [Epoch 150/200] [Batch 200/674] [D loss: 0.0044] [G loss: 8.1742]
# [Epoch 150/200] [Batch 400/674] [D loss: 0.0261] [G loss: 5.7285]
# [Epoch 150/200] [Batch 600/674] [D loss: 0.0082] [G loss: 7.3228]
# [Epoch 151/200] [Batch 200/674] [D loss: 0.0055] [G loss: 8.4056]
# [Epoch 151/200] [Batch 400/674] [D loss: 0.0101] [G loss: 7.5355]
# [Epoch 151/200] [Batch 600/674] [D loss: 0.0025] [G loss: 8.7499]
# [Epoch 152/200] [Batch 200/674] [D loss: 0.0067] [G loss: 7.3804]
# [Epoch 152/200] [Batch 400/674] [D loss: 0.0036] [G loss: 7.9558]
# [Epoch 152/200] [Batch 600/674] [D loss: 0.0235] [G loss: 7.0238]
# [Epoch 153/200] [Batch 200/674] [D loss: 0.0087] [G loss: 6.9924]
# [Epoch 153/200] [Batch 400/674] [D loss: 0.0117] [G loss: 6.7151]
# [Epoch 153/200] [Batch 600/674] [D loss: 0.0105] [G loss: 7.4192]
# [Epoch 154/200] [Batch 200/674] [D loss: 0.0036] [G loss: 7.2231]
# [Epoch 154/200] [Batch 400/674] [D loss: 0.0042] [G loss: 7.6626]
# [Epoch 154/200] [Batch 600/674] [D loss: 0.0024] [G loss: 7.5122]
# [Epoch 155/200] [Batch 200/674] [D loss: 0.0024] [G loss: 8.2104]
# [Epoch 155/200] [Batch 400/674] [D loss: 0.0042] [G loss: 8.1294]
# [Epoch 155/200] [Batch 600/674] [D loss: 0.0092] [G loss: 8.7947]
# [Epoch 156/200] [Batch 200/674] [D loss: 0.1497] [G loss: 8.5886]
# [Epoch 156/200] [Batch 400/674] [D loss: 0.0213] [G loss: 6.7885]
# [Epoch 156/200] [Batch 600/674] [D loss: 0.0118] [G loss: 6.6026]
# [Epoch 157/200] [Batch 200/674] [D loss: 0.0074] [G loss: 6.3577]
# [Epoch 157/200] [Batch 400/674] [D loss: 0.0044] [G loss: 7.6295]
# [Epoch 157/200] [Batch 600/674] [D loss: 0.0299] [G loss: 8.6294]
# [Epoch 158/200] [Batch 200/674] [D loss: 0.0156] [G loss: 6.9101]
# [Epoch 158/200] [Batch 400/674] [D loss: 0.0015] [G loss: 8.7828]
# [Epoch 158/200] [Batch 600/674] [D loss: 0.0055] [G loss: 8.5552]
# [Epoch 159/200] [Batch 200/674] [D loss: 0.0280] [G loss: 8.4063]
# [Epoch 159/200] [Batch 400/674] [D loss: 0.0073] [G loss: 6.8804]
# [Epoch 159/200] [Batch 600/674] [D loss: 0.0113] [G loss: 7.4905]
# [Epoch 160/200] [Batch 200/674] [D loss: 0.0080] [G loss: 7.0156]
# [Epoch 160/200] [Batch 400/674] [D loss: 0.0067] [G loss: 7.2814]
# [Epoch 160/200] [Batch 600/674] [D loss: 0.0041] [G loss: 7.8456]
# [Epoch 161/200] [Batch 200/674] [D loss: 0.0389] [G loss: 7.2802]
# [Epoch 161/200] [Batch 400/674] [D loss: 0.0071] [G loss: 7.7758]
# [Epoch 161/200] [Batch 600/674] [D loss: 0.0149] [G loss: 7.1261]
# [Epoch 162/200] [Batch 200/674] [D loss: 0.0088] [G loss: 7.8255]
# [Epoch 162/200] [Batch 400/674] [D loss: 0.0031] [G loss: 8.0868]
# [Epoch 162/200] [Batch 600/674] [D loss: 0.0058] [G loss: 8.6199]
# [Epoch 163/200] [Batch 200/674] [D loss: 0.0042] [G loss: 8.1290]
# [Epoch 163/200] [Batch 400/674] [D loss: 0.0059] [G loss: 9.5243]
# [Epoch 163/200] [Batch 600/674] [D loss: 0.0697] [G loss: 7.6256]
# [Epoch 164/200] [Batch 200/674] [D loss: 0.0181] [G loss: 7.0689]
# [Epoch 164/200] [Batch 400/674] [D loss: 0.0034] [G loss: 7.3016]
# [Epoch 164/200] [Batch 600/674] [D loss: 0.0091] [G loss: 6.9753]
# [Epoch 165/200] [Batch 200/674] [D loss: 0.0075] [G loss: 8.5973]
# [Epoch 165/200] [Batch 400/674] [D loss: 0.0060] [G loss: 7.3840]
# [Epoch 165/200] [Batch 600/674] [D loss: 0.0040] [G loss: 7.7673]
# [Epoch 166/200] [Batch 200/674] [D loss: 0.0119] [G loss: 9.4307]
# [Epoch 166/200] [Batch 400/674] [D loss: 0.0055] [G loss: 7.4387]
# [Epoch 166/200] [Batch 600/674] [D loss: 0.0032] [G loss: 8.7571]
# [Epoch 167/200] [Batch 200/674] [D loss: 0.0526] [G loss: 8.7875]
# [Epoch 167/200] [Batch 400/674] [D loss: 0.0085] [G loss: 6.8793]
# [Epoch 167/200] [Batch 600/674] [D loss: 0.0226] [G loss: 6.3255]
# [Epoch 168/200] [Batch 200/674] [D loss: 0.0085] [G loss: 7.9571]
# [Epoch 168/200] [Batch 400/674] [D loss: 0.0101] [G loss: 8.5340]
# [Epoch 168/200] [Batch 600/674] [D loss: 0.0020] [G loss: 8.7453]
# [Epoch 169/200] [Batch 200/674] [D loss: 0.0107] [G loss: 7.5667]
# [Epoch 169/200] [Batch 400/674] [D loss: 0.0065] [G loss: 7.2664]
# [Epoch 169/200] [Batch 600/674] [D loss: 0.0036] [G loss: 8.6284]
# [Epoch 170/200] [Batch 200/674] [D loss: 0.0060] [G loss: 9.3152]
# [Epoch 170/200] [Batch 400/674] [D loss: 0.0089] [G loss: 10.0873]
# [Epoch 170/200] [Batch 600/674] [D loss: 0.6617] [G loss: 9.7691]
# [Epoch 171/200] [Batch 200/674] [D loss: 0.0076] [G loss: 7.3894]
# [Epoch 171/200] [Batch 400/674] [D loss: 0.0058] [G loss: 7.0796]
# [Epoch 171/200] [Batch 600/674] [D loss: 0.0139] [G loss: 6.1404]
# [Epoch 172/200] [Batch 200/674] [D loss: 0.0036] [G loss: 8.0437]
# [Epoch 172/200] [Batch 400/674] [D loss: 0.0054] [G loss: 8.3882]
# [Epoch 172/200] [Batch 600/674] [D loss: 0.0072] [G loss: 7.3427]
# [Epoch 173/200] [Batch 200/674] [D loss: 0.0046] [G loss: 7.5403]
# [Epoch 173/200] [Batch 400/674] [D loss: 0.0029] [G loss: 8.6626]
# [Epoch 173/200] [Batch 600/674] [D loss: 0.9728] [G loss: 5.2229]
# [Epoch 174/200] [Batch 200/674] [D loss: 0.0251] [G loss: 7.5681]
# [Epoch 174/200] [Batch 400/674] [D loss: 0.0138] [G loss: 7.4141]
# [Epoch 174/200] [Batch 600/674] [D loss: 0.0031] [G loss: 8.3806]
# [Epoch 175/200] [Batch 200/674] [D loss: 0.0033] [G loss: 7.6500]
# [Epoch 175/200] [Batch 400/674] [D loss: 0.0117] [G loss: 6.8894]
# [Epoch 175/200] [Batch 600/674] [D loss: 0.0025] [G loss: 8.0933]
# [Epoch 176/200] [Batch 200/674] [D loss: 0.0054] [G loss: 8.2513]
# [Epoch 176/200] [Batch 400/674] [D loss: 0.0073] [G loss: 8.1234]
# [Epoch 176/200] [Batch 600/674] [D loss: 0.0172] [G loss: 6.6511]
# [Epoch 177/200] [Batch 200/674] [D loss: 0.0020] [G loss: 8.6274]
# [Epoch 177/200] [Batch 400/674] [D loss: 0.0343] [G loss: 5.6621]
# [Epoch 177/200] [Batch 600/674] [D loss: 0.0947] [G loss: 7.7652]
# [Epoch 178/200] [Batch 200/674] [D loss: 0.0288] [G loss: 6.3042]
# [Epoch 178/200] [Batch 400/674] [D loss: 0.0148] [G loss: 8.0395]
# [Epoch 178/200] [Batch 600/674] [D loss: 0.0119] [G loss: 7.7551]
# [Epoch 179/200] [Batch 200/674] [D loss: 0.0009] [G loss: 9.6631]
# [Epoch 179/200] [Batch 400/674] [D loss: 0.0029] [G loss: 11.3468]
# [Epoch 179/200] [Batch 600/674] [D loss: 0.0073] [G loss: 8.4131]
# [Epoch 180/200] [Batch 200/674] [D loss: 0.0015] [G loss: 9.4138]
# [Epoch 180/200] [Batch 400/674] [D loss: 0.0083] [G loss: 8.0871]
# [Epoch 180/200] [Batch 600/674] [D loss: 0.0008] [G loss: 8.8291]
# [Epoch 181/200] [Batch 200/674] [D loss: 0.8441] [G loss: 5.2376]
# [Epoch 181/200] [Batch 400/674] [D loss: 0.0352] [G loss: 6.7148]
# [Epoch 181/200] [Batch 600/674] [D loss: 0.0405] [G loss: 6.9438]
# [Epoch 182/200] [Batch 200/674] [D loss: 0.0232] [G loss: 6.4979]
# [Epoch 182/200] [Batch 400/674] [D loss: 0.0115] [G loss: 6.7279]
# [Epoch 182/200] [Batch 600/674] [D loss: 0.0076] [G loss: 7.7660]
# [Epoch 183/200] [Batch 200/674] [D loss: 0.0071] [G loss: 8.0440]
# [Epoch 183/200] [Batch 400/674] [D loss: 0.0041] [G loss: 7.2606]
# [Epoch 183/200] [Batch 600/674] [D loss: 0.0048] [G loss: 7.7457]
# [Epoch 184/200] [Batch 200/674] [D loss: 0.0042] [G loss: 7.7382]
# [Epoch 184/200] [Batch 400/674] [D loss: 0.0150] [G loss: 6.5609]
# [Epoch 184/200] [Batch 600/674] [D loss: 0.0030] [G loss: 8.1788]
# [Epoch 185/200] [Batch 200/674] [D loss: 0.0017] [G loss: 7.8959]
# [Epoch 185/200] [Batch 400/674] [D loss: 0.0052] [G loss: 7.7161]
# [Epoch 185/200] [Batch 600/674] [D loss: 0.0025] [G loss: 7.8054]
# [Epoch 186/200] [Batch 200/674] [D loss: 0.0222] [G loss: 7.1125]
# [Epoch 186/200] [Batch 400/674] [D loss: 0.0160] [G loss: 7.8194]
# [Epoch 186/200] [Batch 600/674] [D loss: 0.0119] [G loss: 7.5631]
# [Epoch 187/200] [Batch 200/674] [D loss: 0.0024] [G loss: 8.4081]
# [Epoch 187/200] [Batch 400/674] [D loss: 0.0037] [G loss: 8.0571]
# [Epoch 187/200] [Batch 600/674] [D loss: 0.0028] [G loss: 8.3980]
# [Epoch 188/200] [Batch 200/674] [D loss: 0.0042] [G loss: 7.9297]
# [Epoch 188/200] [Batch 400/674] [D loss: 0.0116] [G loss: 7.0295]
# [Epoch 188/200] [Batch 600/674] [D loss: 0.0022] [G loss: 8.2835]
# [Epoch 189/200] [Batch 200/674] [D loss: 0.0168] [G loss: 7.6116]
# [Epoch 189/200] [Batch 400/674] [D loss: 0.0298] [G loss: 7.3386]
# [Epoch 189/200] [Batch 600/674] [D loss: 0.0041] [G loss: 7.9210]
# [Epoch 190/200] [Batch 200/674] [D loss: 0.0044] [G loss: 7.2871]
# [Epoch 190/200] [Batch 400/674] [D loss: 0.0084] [G loss: 8.0777]
# [Epoch 190/200] [Batch 600/674] [D loss: 0.0058] [G loss: 8.0421]
# [Epoch 191/200] [Batch 200/674] [D loss: 0.0029] [G loss: 8.1871]
# [Epoch 191/200] [Batch 400/674] [D loss: 0.0137] [G loss: 8.2445]
# [Epoch 191/200] [Batch 600/674] [D loss: 0.0082] [G loss: 7.8495]
# [Epoch 192/200] [Batch 200/674] [D loss: 0.0797] [G loss: 8.4445]
# [Epoch 192/200] [Batch 400/674] [D loss: 0.0141] [G loss: 7.5435]
# [Epoch 192/200] [Batch 600/674] [D loss: 0.0041] [G loss: 6.9540]
# [Epoch 193/200] [Batch 200/674] [D loss: 0.0057] [G loss: 7.9773]
# [Epoch 193/200] [Batch 400/674] [D loss: 0.0026] [G loss: 8.3931]
# [Epoch 193/200] [Batch 600/674] [D loss: 0.0064] [G loss: 7.6139]
# [Epoch 194/200] [Batch 200/674] [D loss: 0.0024] [G loss: 8.5639]
# [Epoch 194/200] [Batch 400/674] [D loss: 0.0049] [G loss: 8.5616]
# [Epoch 194/200] [Batch 600/674] [D loss: 0.0411] [G loss: 8.5508]
# [Epoch 195/200] [Batch 200/674] [D loss: 0.0062] [G loss: 7.5199]
# [Epoch 195/200] [Batch 400/674] [D loss: 0.0088] [G loss: 8.7093]
# [Epoch 195/200] [Batch 600/674] [D loss: 0.0148] [G loss: 7.8635]
# [Epoch 196/200] [Batch 200/674] [D loss: 0.0048] [G loss: 7.7406]
# [Epoch 196/200] [Batch 400/674] [D loss: 0.0037] [G loss: 7.7256]
# [Epoch 196/200] [Batch 600/674] [D loss: 0.0042] [G loss: 8.8035]
# [Epoch 197/200] [Batch 200/674] [D loss: 0.0225] [G loss: 7.4604]
# [Epoch 197/200] [Batch 400/674] [D loss: 0.0052] [G loss: 9.8649]
# [Epoch 197/200] [Batch 600/674] [D loss: 0.0419] [G loss: 7.4364]
# [Epoch 198/200] [Batch 200/674] [D loss: 0.0081] [G loss: 7.5672]
# [Epoch 198/200] [Batch 400/674] [D loss: 0.0072] [G loss: 8.4742]
# [Epoch 198/200] [Batch 600/674] [D loss: 0.0070] [G loss: 8.3574]
# [Epoch 199/200] [Batch 200/674] [D loss: 0.0086] [G loss: 9.7906]
# [Epoch 199/200] [Batch 400/674] [D loss: 0.0043] [G loss: 8.9894]
# [Epoch 199/200] [Batch 600/674] [D loss: 0.0022] [G loss: 7.6543]
# [Epoch 200/200] [Batch 200/674] [D loss: 0.0025] [G loss: 9.9895]
# [Epoch 200/200] [Batch 400/674] [D loss: 0.0022] [G loss: 8.6141]
# [Epoch 200/200] [Batch 600/674] [D loss: 0.0016] [G loss: 10.3319]
# Training completed!
